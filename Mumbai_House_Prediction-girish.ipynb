# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Mumbai.csv')

# %%
data.head()
# Out:
#      Price  Area  Location  No. of Bedrooms  Resale  MaintenanceStaff  \
# 0  4850000   720  Kharghar                1       1                 1
# 1  4500000   600  Kharghar                1       1                 1
# 2  6700000   650  Kharghar                1       1                 1
# 3  4500000   650  Kharghar                1       1                 1
# 4  5000000   665  Kharghar                1       1                 1
#
#    Gymnasium  SwimmingPool  LandscapedGardens  JoggingTrack  ...  \
# 0          0             0                  0             0  ...
# 1          1             1                  0             1  ...
# 2          1             1                  0             1  ...
# 3          0             0                  1             0  ...
# 4          0             0                  1             0  ...
#
#    LiftAvailable  BED  VaastuCompliant  Microwave  GolfCourse  TV  \
# 0              1    0                1          0           0   0
# ...

# %%
data.shape
# Out:
# (7719, 40)

# %%
# calculate and visualize correlation matrix
matrix = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(matrix, vmax=1, square=True, cmap="BuPu",annot_kws={'size':8}, annot=True)
matrix
# Out:
#                         Price      Area  No. of Bedrooms    Resale  \
# Price                1.000000  0.299172         0.272048 -0.046493
# Area                 0.299172  1.000000         0.810016 -0.024114
# No. of Bedrooms      0.272048  0.810016         1.000000 -0.113498
# Resale              -0.046493 -0.024114        -0.113498  1.000000
# MaintenanceStaff    -0.011882 -0.067163        -0.026347 -0.110552
# Gymnasium           -0.007093 -0.059166        -0.018536 -0.121058
# SwimmingPool        -0.003388 -0.055341        -0.016159 -0.124162
# LandscapedGardens   -0.005336 -0.059304        -0.020508 -0.127375
# JoggingTrack        -0.007419 -0.057962        -0.018633 -0.126384
# RainWaterHarvesting -0.006354 -0.059207        -0.019177 -0.117759
# IndoorGames         -0.005695 -0.059026        -0.019542 -0.125745
# ShoppingMall        -0.007531 -0.062115        -0.022074 -0.121176
# Intercom            -0.007612 -0.059300        -0.019651 -0.124504
# ...

# %%
data.drop(columns=['Resale','MaintenanceStaff','LandscapedGardens','Gymnasium','SwimmingPool','JoggingTrack','ClubHouse','CarParking','RainWaterHarvesting','IndoorGames','LiftAvailable','ShoppingMall','Intercom','SportsFacility','ATM','School','24X7Security','PowerBackup','StaffQuarter','Cafeteria','MultipurposeRoom','Hospital','WashingMachine','Gasconnection','AC','Wifi','Childrensplayarea','BED','VaastuCompliant','Microwave','GolfCourse','TV','DiningTable','Sofa','Wardrobe','Refrigerator','SwimmingPool','LiftAvailable'
],inplace=True)

# %%
data.head()
# Out:
#      Price  Area  Location  No. of Bedrooms
# 0  4850000   720  Kharghar                1
# 1  4500000   600  Kharghar                1
# 2  6700000   650  Kharghar                1
# 3  4500000   650  Kharghar                1
# 4  5000000   665  Kharghar                1

# %%
matrix = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(matrix, vmax=1, square=True, cmap="BuPu",annot_kws={'size':8}, annot=True)
matrix
# Out:
#                     Price      Area  No. of Bedrooms
# Price            1.000000  0.299172         0.272048
# Area             0.299172  1.000000         0.810016
# No. of Bedrooms  0.272048  0.810016         1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7719 entries, 0 to 7718
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            7719 non-null   int64
#  1   Area             7719 non-null   int64
#  2   Location         7719 non-null   object
#  3   No. of Bedrooms  7719 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 241.3+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# 8500000      129
# 8000000      116
# 4500000      109
# 11000000     108
# 7500000      107
#             ...
# 5050000        1
# 3920000        1
# 7311000        1
# 4280000        1
# 153600000      1
# Name: Price, Length: 977, dtype: int64
# ********************
# 650     319
# 1050    178
# 600     165
# 1100    162
# 1150    120
#        ...
# 1246      1
# 353       1
# 5320      1
# 369       1
# 2061      1
# Name: Area, Length: 1140, dtype: int64
# ********************
# Kharghar              681
# Thane West            577
# Mira Road East        481
# Ulwe                  391
# Nala Sopara           225
#                      ...
# Bhayandar West          1
# Kurla East              1
# Churchgate              1
# ulhasnagar 4            1
# Tilak Nagar Mumbai      1
# Name: Location, Length: 413, dtype: int64
# ********************
# 2    3206
# 1    2763
# 3    1472
# 4     224
# 5      44
# 6       8
# 7       2
# Name: No. of Bedrooms, dtype: int64
# ...

# %%
data.isna().sum()
# Out:
# Price              0
# Area               0
# Location           0
# No. of Bedrooms    0
# dtype: int64

# %%
data['price_per_sqft'] = data['Price']/ data['Area']

# %%
data['price_per_sqft']
# Out:
# 0        6736.111111
# 1        7500.000000
# 2       10307.692308
# 3        6923.076923
# 4        7518.796992
#             ...
# 7714    12288.135593
# 7715    27358.490566
# 7716     5857.142857
# 7717     2763.819095
# 7718     2696.078431
# Name: price_per_sqft, Length: 7719, dtype: float64

# %%
data.describe()
# Out:
#               Price         Area  No. of Bedrooms  price_per_sqft
# count  7.719000e+03  7719.000000      7719.000000     7719.000000
# mean   1.506165e+07   998.409250         1.913331    16169.701661
# std    2.052100e+07   550.967809         0.855376    19577.703163
# min    2.000000e+06   200.000000         1.000000      460.526316
# 25%    5.300000e+06   650.000000         1.000000     6461.538462
# 50%    9.500000e+06   900.000000         2.000000    10410.094637
# 75%    1.700000e+07  1177.000000         2.000000    18736.997226
# max    4.200000e+08  8511.000000         7.000000   400000.000000

# %%
data['Location'].value_counts()
# Out:
# Kharghar              681
# Thane West            577
# Mira Road East        481
# Ulwe                  391
# Nala Sopara           225
#                      ...
# Bhayandar West          1
# Kurla East              1
# Churchgate              1
# ulhasnagar 4            1
# Tilak Nagar Mumbai      1
# Name: Location, Length: 413, dtype: int64

# %%
data['Location']=data['Location'].apply(lambda x: x.strip())
location_count=data['Location'].value_counts()

# %%
location_count
# Out:
# Kharghar              681
# Thane West            577
# Mira Road East        481
# Ulwe                  391
# Nala Sopara           225
#                      ...
# Bhayandar West          1
# Kurla East              1
# Churchgate              1
# ulhasnagar 4            1
# Tilak Nagar Mumbai      1
# Name: Location, Length: 413, dtype: int64

# %%
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# Rajendra Nagar        10
# Prabhadevi            10
# Sector 10             10
# Mumbai Central        10
# Kalamboli             10
#                       ..
# Bhayandar West         1
# Kurla East             1
# Churchgate             1
# ulhasnagar 4           1
# Tilak Nagar Mumbai     1
# Name: Location, Length: 312, dtype: int64

# %%
data['Location']=data['Location'].apply(lambda x: 'Other' if x in location_count_less_10 else x)

# %%
data['Location'].value_counts()
# Out:
# Other                 824
# Kharghar              681
# Thane West            577
# Mira Road East        481
# Ulwe                  391
#                      ...
# Majiwada               12
# Palghar                11
# Kurla West             11
# Lower Parel            11
# Sector 19 Kharghar     11
# Name: Location, Length: 102, dtype: int64
